# %%
import pandas as pd
bookings = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio//KSCHOOL/Master_Data_Science/master_data/master_data/challenge/bookings.csv', nrows=100000)
bookings
# Out:
#       act_date           ^source^pos_ctry^pos_iata^pos_oid  ^rloc          ^cre_date           ^duration^distance^dep_port^dep_city^dep_ctry^arr_port^arr_city^arr_ctry^lst_port^lst_city^lst_ctry^brd_port^brd_city^brd_ctry^off_port^off_city^off_ctry^mkt_port^mkt_city^mkt_ctry^intl^route          ^carrier^bkg_class^cab_class^brd_time           ^off_time           ^pax^year^month^oid
# 0      2013-03-05 00:00:00^1A    ^DE      ^a68dd7ae95...
# 1      2013-03-26 00:00:00^1A    ^US      ^e612b9eeee...
# 2      2013-03-26 00:00:00^1A    ^US      ^e612b9eeee...
# 3      2013-03-26 00:00:00^1A    ^AU      ^0f984b3bb6...
# 4      2013-03-26 00:00:00^1A    ^AU      ^0f984b3bb6...
# ...                                                  ...
# 99995  2013-03-03 00:00:00^1G    ^FR      ^a17ff438d6...
# 99996  2013-03-05 00:00:00^1G    ^FR      ^a17ff438d6...
# 99997  2013-03-05 00:00:00^1G    ^FR      ^a17ff438d6...
# 99998  2013-03-20 00:00:00^1G    ^ZA      ^355368d5d7...
# ...

# %%
bookings = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio//KSCHOOL/Master_Data_Science/master_data/master_data/challenge/bookings.csv', delimiter='^', nrows=100000)
bookings
# Out:
#        act_date             source  pos_ctry  \
# 0      2013-03-05 00:00:00  1A      DE
# 1      2013-03-26 00:00:00  1A      US
# 2      2013-03-26 00:00:00  1A      US
# 3      2013-03-26 00:00:00  1A      AU
# 4      2013-03-26 00:00:00  1A      AU
# ...                    ...     ...       ...
# 99995  2013-03-03 00:00:00  1G      FR
# 99996  2013-03-05 00:00:00  1G      FR
# 99997  2013-03-05 00:00:00  1G      FR
# 99998  2013-03-20 00:00:00  1G      ZA
# 99999  2013-03-20 00:00:00  1G      ZA
#
#                                pos_iata                         pos_oid    \
# 0      a68dd7ae953c8acfb187a1af2dcbe123  1a11ae49fcbf545fd2afc1a24d88d2b7
# 1      e612b9eeeee6f17f42d9b0d3b79e75ca  7437560d8f276d6d05eeb806d9e7edee
# 2      e612b9eeeee6f17f42d9b0d3b79e75ca  7437560d8f276d6d05eeb806d9e7edee
# 3      0f984b3bb6bd06661c95529bbd6193bc  36472c6dbaf7afec9136ac40364e2794
# 4      0f984b3bb6bd06661c95529bbd6193bc  36472c6dbaf7afec9136ac40364e2794
# ...

# %%
len(bookings.columns)
# Out:
# 38

# %%
print(bookings.columns)
# Out:
# Index(['act_date           ', 'source', 'pos_ctry', 'pos_iata', 'pos_oid  ',
#        'rloc          ', 'cre_date           ', 'duration', 'distance',
#        'dep_port', 'dep_city', 'dep_ctry', 'arr_port', 'arr_city', 'arr_ctry',
#        'lst_port', 'lst_city', 'lst_ctry', 'brd_port', 'brd_city', 'brd_ctry',
#        'off_port', 'off_city', 'off_ctry', 'mkt_port', 'mkt_city', 'mkt_ctry',
#        'intl', 'route          ', 'carrier', 'bkg_class', 'cab_class',
#        'brd_time           ', 'off_time           ', 'pax', 'year', 'month',
#        'oid      '],
#       dtype='object')

# %%
bookings.columns = bookings.columns.str.replace(' ', '')
print(bookings.columns)
# Out:
# Index(['act_date', 'source', 'pos_ctry', 'pos_iata', 'pos_oid', 'rloc',
#        'cre_date', 'duration', 'distance', 'dep_port', 'dep_city', 'dep_ctry',
#        'arr_port', 'arr_city', 'arr_ctry', 'lst_port', 'lst_city', 'lst_ctry',
#        'brd_port', 'brd_city', 'brd_ctry', 'off_port', 'off_city', 'off_ctry',
#        'mkt_port', 'mkt_city', 'mkt_ctry', 'intl', 'route', 'carrier',
#        'bkg_class', 'cab_class', 'brd_time', 'off_time', 'pax', 'year',
#        'month', 'oid'],
#       dtype='object')

# %%
bookings = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio//KSCHOOL/Master_Data_Science/master_data/master_data/challenge/bookings.csv.bz2', nrows=100000, delimiter='^', usecols=['year','arr_port','pax'])
bookings
# Out:
#        arr_port  pax  year
# 0      LHR        -1  2013
# 1      CLT         1  2013
# 2      CLT         1  2013
# 3      SVO         1  2013
# 4      SVO         1  2013
# ...         ...  ...   ...
# 99995  IXL         2  2013
# 99996  IXL        -2  2013
# 99997  IXL        -2  2013
# 99998  CPT         2  2013
# 99999  CPT         2  2013
#
# [100000 rows x 3 columns]

# %%
bookings['abs_pax'] = bookings['pax'].abs()
bookings
# Out:
#        arr_port  pax  year  abs_pax
# 0      LHR        -1  2013        1
# 1      CLT         1  2013        1
# 2      CLT         1  2013        1
# 3      SVO         1  2013        1
# 4      SVO         1  2013        1
# ...         ...  ...   ...      ...
# 99995  IXL         2  2013        2
# 99996  IXL        -2  2013        2
# 99997  IXL        -2  2013        2
# 99998  CPT         2  2013        2
# 99999  CPT         2  2013        2
#
# [100000 rows x 4 columns]

# %%
bookings.groupby('arr_port')['abs_pax'].sum().sort_values(ascending=False).head(10)
# Out:
# arr_port
# LHR         3128
# JFK         2759
# LAX         2513
# BKK         2481
# CDG         2472
# MIA         2147
# MCO         2127
# DXB         2079
# FCO         1905
# SFO         1739
# Name: abs_pax, dtype: int64

# %%
bookings.groupby('arr_port')abs_pax.sum().sort_values(ascending=False).head(10)
# Out:
#   File "<ipython-input-39-b7fd75939a85>", line 1
#     bookings.groupby('arr_port')abs_pax.sum().sort_values(ascending=False).head(10)
#                                       ^
# SyntaxError: invalid syntax

# %%
df_bookings.head(bookings)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-54e433df10e7> in <module>
# ----> 1 df_bookings.head(bookings)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in head(self, n)
#    4733         """
#    4734
# -> 4735         return self.iloc[:n]
#    4736
#    4737     def tail(self, n=5):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2135     def _getitem_axis(self, key, axis: int):
#    2136         if isinstance(key, slice):
# ...

# %%
searchers = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio/KSCHOOL/Master_Data_Science/master_data/master_data/challenge/searchers.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a8f0209eb84d> in <module>
# ----> 1 searchers = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio/KSCHOOL/Master_Data_Science/master_data/master_data/challenge/searchers.csv')
#
# ...

# %%
bzcat searches.csv.bz2 | more
# Out:
#   File "<ipython-input-5-d9e50387b21a>", line 1
#     bzcat searches.csv.bz2 | more
#                  ^
# SyntaxError: invalid syntax

# %%
bookings = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio//KSCHOOL/Master_Data_Science/master_data/master_data/challenge/bookings.csv.bz2', nrows=100000, delimiter='^')
bookings
# Out:
#        act_date             source  pos_ctry  \
# 0      2013-03-05 00:00:00  1A      DE
# 1      2013-03-26 00:00:00  1A      US
# 2      2013-03-26 00:00:00  1A      US
# 3      2013-03-26 00:00:00  1A      AU
# 4      2013-03-26 00:00:00  1A      AU
# ...                    ...     ...       ...
# 99995  2013-03-03 00:00:00  1G      FR
# 99996  2013-03-05 00:00:00  1G      FR
# 99997  2013-03-05 00:00:00  1G      FR
# 99998  2013-03-20 00:00:00  1G      ZA
# 99999  2013-03-20 00:00:00  1G      ZA
#
#                                pos_iata                         pos_oid    \
# 0      a68dd7ae953c8acfb187a1af2dcbe123  1a11ae49fcbf545fd2afc1a24d88d2b7
# 1      e612b9eeeee6f17f42d9b0d3b79e75ca  7437560d8f276d6d05eeb806d9e7edee
# 2      e612b9eeeee6f17f42d9b0d3b79e75ca  7437560d8f276d6d05eeb806d9e7edee
# 3      0f984b3bb6bd06661c95529bbd6193bc  36472c6dbaf7afec9136ac40364e2794
# 4      0f984b3bb6bd06661c95529bbd6193bc  36472c6dbaf7afec9136ac40364e2794
# ...

# %%
print(bookings.columns)
# Out:
# Index(['act_date           ', 'source', 'pos_ctry', 'pos_iata', 'pos_oid  ',
#        'rloc          ', 'cre_date           ', 'duration', 'distance',
#        'dep_port', 'dep_city', 'dep_ctry', 'arr_port', 'arr_city', 'arr_ctry',
#        'lst_port', 'lst_city', 'lst_ctry', 'brd_port', 'brd_city', 'brd_ctry',
#        'off_port', 'off_city', 'off_ctry', 'mkt_port', 'mkt_city', 'mkt_ctry',
#        'intl', 'route          ', 'carrier', 'bkg_class', 'cab_class',
#        'brd_time           ', 'off_time           ', 'pax', 'year', 'month',
#        'oid      '],
#       dtype='object')

# %%
bookings.columns = bookings.columns.str.replace(' ', '')
print(bookings.columns)
# Out:
# Index(['act_date', 'source', 'pos_ctry', 'pos_iata', 'pos_oid', 'rloc',
#        'cre_date', 'duration', 'distance', 'dep_port', 'dep_city', 'dep_ctry',
#        'arr_port', 'arr_city', 'arr_ctry', 'lst_port', 'lst_city', 'lst_ctry',
#        'brd_port', 'brd_city', 'brd_ctry', 'off_port', 'off_city', 'off_ctry',
#        'mkt_port', 'mkt_city', 'mkt_ctry', 'intl', 'route', 'carrier',
#        'bkg_class', 'cab_class', 'brd_time', 'off_time', 'pax', 'year',
#        'month', 'oid'],
#       dtype='object')

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 38 columns):
# act_date     100000 non-null object
# source       100000 non-null object
# pos_ctry     100000 non-null object
# pos_iata     100000 non-null object
# pos_oid      100000 non-null object
# rloc         100000 non-null object
# cre_date     100000 non-null object
# duration     100000 non-null int64
# distance     100000 non-null int64
# dep_port     100000 non-null object
# dep_city     100000 non-null object
# dep_ctry     100000 non-null object
# arr_port     100000 non-null object
# arr_city     100000 non-null object
# arr_ctry     100000 non-null object
# lst_port     100000 non-null object
# lst_city     100000 non-null object
# lst_ctry     100000 non-null object
# brd_port     100000 non-null object
# brd_city     100000 non-null object
# brd_ctry     100000 non-null object
# off_port     100000 non-null object
# off_city     100000 non-null object
# ...

# %%
len(bookings.columns)
# Out:
# 38

# %%
bookings = pd.read_csv('/Users/MGARRI2/OneDrive - MAPFRE/Escritorio//KSCHOOL/Master_Data_Science/master_data/master_data/challenge/bookings.csv.bz2', nrows=100000, delimiter='^', usecols=['year','arr_port','pax'])
bookings
# Out:
#        arr_port  pax  year
# 0      LHR        -1  2013
# 1      CLT         1  2013
# 2      CLT         1  2013
# 3      SVO         1  2013
# 4      SVO         1  2013
# ...         ...  ...   ...
# 99995  IXL         2  2013
# 99996  IXL        -2  2013
# 99997  IXL        -2  2013
# 99998  CPT         2  2013
# 99999  CPT         2  2013
#
# [100000 rows x 3 columns]

# %%
bookings['abs_pax'] = bookings['pax'].abs()
bookings
# Out:
#        arr_port  pax  year  abs_pax
# 0      LHR        -1  2013        1
# 1      CLT         1  2013        1
# 2      CLT         1  2013        1
# 3      SVO         1  2013        1
# 4      SVO         1  2013        1
# ...         ...  ...   ...      ...
# 99995  IXL         2  2013        2
# 99996  IXL        -2  2013        2
# 99997  IXL        -2  2013        2
# 99998  CPT         2  2013        2
# 99999  CPT         2  2013        2
#
# [100000 rows x 4 columns]

# %%
bookings.groupby('arr_port')['abs_pax'].sum().sort_values(ascending=False).head(10)
# Out:
# arr_port
# LHR         3128
# JFK         2759
# LAX         2513
# BKK         2481
# CDG         2472
# MIA         2147
# MCO         2127
# DXB         2079
# FCO         1905
# SFO         1739
# Name: abs_pax, dtype: int64
